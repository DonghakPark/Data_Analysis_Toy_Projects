# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from time import time
import datetime
import gc
from scipy.signal import find_peaks, peak_widths, peak_prominences
# Model
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

import lightgbm as lgb
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import plot_importance
# Ensemble
from scipy.optimize import minimize
from sklearn.metrics import log_loss
from sklearn.model_selection import GridSearchCV
import matplotlib.pylab as plt

##LGBM
from lightgbm import LGBMClassifier, plot_importance

# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4
from google.colab import drive
drive.mount('/content/drvie')
# Out:
# Drive already mounted at /content/drvie; to attempt to forcibly remount, call drive.mount("/content/drvie", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train = pd.read_csv('/content/drvie/My Drive/Colab Notebooks/Data/train.csv',index_col=0)
test = pd.read_csv('/content/drvie/My Drive/Colab Notebooks//Data/test.csv',index_col=0)
sample_submission = pd.read_csv('/content/drvie/My Drive/Colab Notebooks/Data/sample_submission.csv',index_col=0)

# %%
train_x = train.drop(columns='class', axis=1)
train_y = train['class']
test_x = test

# %%
lgb = LGBMClassifier(n_estimators=1000,device='gpu')
evals = [(X_test, y_test)]
lgb_pred = lgb.fit(X_train, y_train, early_stopping_rounds= 100, eval_metric="logloss", eval_set=evals, verbose = True)
# Out:
# [1]	valid_0's multi_logloss: 0.856476
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.755864
# [3]	valid_0's multi_logloss: 0.67545
# [4]	valid_0's multi_logloss: 0.609697
# [5]	valid_0's multi_logloss: 0.555025
# [6]	valid_0's multi_logloss: 0.509211
# [7]	valid_0's multi_logloss: 0.47052
# [8]	valid_0's multi_logloss: 0.437614
# [9]	valid_0's multi_logloss: 0.409472
# [10]	valid_0's multi_logloss: 0.385107
# [11]	valid_0's multi_logloss: 0.364083
# [12]	valid_0's multi_logloss: 0.345873
# [13]	valid_0's multi_logloss: 0.329961
# [14]	valid_0's multi_logloss: 0.31602
# [15]	valid_0's multi_logloss: 0.303778
# [16]	valid_0's multi_logloss: 0.29299
# [17]	valid_0's multi_logloss: 0.283466
# [18]	valid_0's multi_logloss: 0.275074
# [19]	valid_0's multi_logloss: 0.267685
# [20]	valid_0's multi_logloss: 0.261146
# [21]	valid_0's multi_logloss: 0.255183
# [22]	valid_0's multi_logloss: 0.249837
# [23]	valid_0's multi_logloss: 0.245035
# [24]	valid_0's multi_logloss: 0.240856
# [25]	valid_0's multi_logloss: 0.236953
# [26]	valid_0's multi_logloss: 0.233298
# [27]	valid_0's multi_logloss: 0.230199
# [28]	valid_0's multi_logloss: 0.227285
# [29]	valid_0's multi_logloss: 0.224667
# [30]	valid_0's multi_logloss: 0.222348
# [31]	valid_0's multi_logloss: 0.220267
# [32]	valid_0's multi_logloss: 0.21839
# [33]	valid_0's multi_logloss: 0.216675
# [34]	valid_0's multi_logloss: 0.215039
# [35]	valid_0's multi_logloss: 0.213576
# [36]	valid_0's multi_logloss: 0.212289
# [37]	valid_0's multi_logloss: 0.211022
# [38]	valid_0's multi_logloss: 0.209887
# [39]	valid_0's multi_logloss: 0.208666
# [40]	valid_0's multi_logloss: 0.207753
# [41]	valid_0's multi_logloss: 0.206939
# [42]	valid_0's multi_logloss: 0.206121
# [43]	valid_0's multi_logloss: 0.205241
# [44]	valid_0's multi_logloss: 0.204599
# [45]	valid_0's multi_logloss: 0.203798
# [46]	valid_0's multi_logloss: 0.2031
# [47]	valid_0's multi_logloss: 0.202462
# [48]	valid_0's multi_logloss: 0.201936
# [49]	valid_0's multi_logloss: 0.201374
# [50]	valid_0's multi_logloss: 0.200951
# [51]	valid_0's multi_logloss: 0.200429
# [52]	valid_0's multi_logloss: 0.199922
# [53]	valid_0's multi_logloss: 0.199421
# [54]	valid_0's multi_logloss: 0.199072
# [55]	valid_0's multi_logloss: 0.198633
# [56]	valid_0's multi_logloss: 0.198332
# [57]	valid_0's multi_logloss: 0.197939
# [58]	valid_0's multi_logloss: 0.197443
# [59]	valid_0's multi_logloss: 0.197097
# [60]	valid_0's multi_logloss: 0.196735
# [61]	valid_0's multi_logloss: 0.196546
# [62]	valid_0's multi_logloss: 0.196315
# [63]	valid_0's multi_logloss: 0.196159
# [64]	valid_0's multi_logloss: 0.19604
# [65]	valid_0's multi_logloss: 0.195648
# [66]	valid_0's multi_logloss: 0.195406
# [67]	valid_0's multi_logloss: 0.195039
# [68]	valid_0's multi_logloss: 0.19473
# [69]	valid_0's multi_logloss: 0.194409
# [70]	valid_0's multi_logloss: 0.194124
# [71]	valid_0's multi_logloss: 0.193994
# [72]	valid_0's multi_logloss: 0.19378
# [73]	valid_0's multi_logloss: 0.193625
# [74]	valid_0's multi_logloss: 0.193508
# [75]	valid_0's multi_logloss: 0.19333
# [76]	valid_0's multi_logloss: 0.193208
# [77]	valid_0's multi_logloss: 0.193101
# [78]	valid_0's multi_logloss: 0.192984
# [79]	valid_0's multi_logloss: 0.192838
# [80]	valid_0's multi_logloss: 0.192735
# [81]	valid_0's multi_logloss: 0.192552
# [82]	valid_0's multi_logloss: 0.192466
# [83]	valid_0's multi_logloss: 0.192302
# [84]	valid_0's multi_logloss: 0.192086
# [85]	valid_0's multi_logloss: 0.191891
# [86]	valid_0's multi_logloss: 0.191682
# [87]	valid_0's multi_logloss: 0.191562
# [88]	valid_0's multi_logloss: 0.191424
# [89]	valid_0's multi_logloss: 0.191329
# [90]	valid_0's multi_logloss: 0.19115
# [91]	valid_0's multi_logloss: 0.191014
# [92]	valid_0's multi_logloss: 0.193192
# [93]	valid_0's multi_logloss: 0.192441
# [94]	valid_0's multi_logloss: 0.191052
# [95]	valid_0's multi_logloss: 0.190932
# [96]	valid_0's multi_logloss: 0.190644
# [97]	valid_0's multi_logloss: 0.190476
# [98]	valid_0's multi_logloss: 0.190304
# [99]	valid_0's multi_logloss: 0.190187
# [100]	valid_0's multi_logloss: 0.190071
# [101]	valid_0's multi_logloss: 0.190008
# [102]	valid_0's multi_logloss: 0.189959
# [103]	valid_0's multi_logloss: 0.189786
# [104]	valid_0's multi_logloss: 0.189784
# [105]	valid_0's multi_logloss: 0.189614
# [106]	valid_0's multi_logloss: 0.190592
# [107]	valid_0's multi_logloss: 0.193302
# [108]	valid_0's multi_logloss: 0.191421
# [109]	valid_0's multi_logloss: 0.190002
# [110]	valid_0's multi_logloss: 0.191843
# [111]	valid_0's multi_logloss: 0.195
# [112]	valid_0's multi_logloss: 0.192467
# [113]	valid_0's multi_logloss: 0.192365
# [114]	valid_0's multi_logloss: 0.192326
# [115]	valid_0's multi_logloss: 0.192229
# [116]	valid_0's multi_logloss: 0.192175
# [117]	valid_0's multi_logloss: 0.192004
# [118]	valid_0's multi_logloss: 0.191929
# [119]	valid_0's multi_logloss: 0.1918
# [120]	valid_0's multi_logloss: 0.191612
# [121]	valid_0's multi_logloss: 0.191443
# [122]	valid_0's multi_logloss: 0.195968
# [123]	valid_0's multi_logloss: 0.192982
# [124]	valid_0's multi_logloss: 0.192142
# [125]	valid_0's multi_logloss: 0.19425
# [126]	valid_0's multi_logloss: 0.194155
# [127]	valid_0's multi_logloss: 0.193789
# [128]	valid_0's multi_logloss: 0.194955
# [129]	valid_0's multi_logloss: 0.194044
# [130]	valid_0's multi_logloss: 0.193899
# [131]	valid_0's multi_logloss: 0.193786
# [132]	valid_0's multi_logloss: 0.193675
# [133]	valid_0's multi_logloss: 0.19362
# [134]	valid_0's multi_logloss: 0.193506
# [135]	valid_0's multi_logloss: 0.193439
# [136]	valid_0's multi_logloss: 0.195603
# [137]	valid_0's multi_logloss: 0.205931
# [138]	valid_0's multi_logloss: 0.194008
# [139]	valid_0's multi_logloss: 0.193946
# [140]	valid_0's multi_logloss: 0.19389
# [141]	valid_0's multi_logloss: 0.194849
# [142]	valid_0's multi_logloss: 0.201596
# [143]	valid_0's multi_logloss: 0.198008
# [144]	valid_0's multi_logloss: 0.199948
# [145]	valid_0's multi_logloss: 0.195564
# [146]	valid_0's multi_logloss: 0.195503
# [147]	valid_0's multi_logloss: 0.194778
# [148]	valid_0's multi_logloss: 0.194747
# [149]	valid_0's multi_logloss: 0.194714
# [150]	valid_0's multi_logloss: 0.194622
# [151]	valid_0's multi_logloss: 0.198411
# [152]	valid_0's multi_logloss: 0.196572
# [153]	valid_0's multi_logloss: 0.194589
# [154]	valid_0's multi_logloss: 0.194452
# [155]	valid_0's multi_logloss: 0.194376
# [156]	valid_0's multi_logloss: 0.19432
# [157]	valid_0's multi_logloss: 0.19421
# [158]	valid_0's multi_logloss: 0.194596
# [159]	valid_0's multi_logloss: 0.194089
# [160]	valid_0's multi_logloss: 0.193981
# [161]	valid_0's multi_logloss: 0.193909
# [162]	valid_0's multi_logloss: 0.193852
# [163]	valid_0's multi_logloss: 0.193783
# [164]	valid_0's multi_logloss: 0.193758
# [165]	valid_0's multi_logloss: 0.193667
# [166]	valid_0's multi_logloss: 0.193576
# [167]	valid_0's multi_logloss: 0.193521
# [168]	valid_0's multi_logloss: 0.193452
# [169]	valid_0's multi_logloss: 0.193412
# [170]	valid_0's multi_logloss: 0.193321
# [171]	valid_0's multi_logloss: 0.193278
# [172]	valid_0's multi_logloss: 0.194054
# [173]	valid_0's multi_logloss: 0.208484
# [174]	valid_0's multi_logloss: 0.19424
# [175]	valid_0's multi_logloss: 0.194213
# [176]	valid_0's multi_logloss: 0.19414
# [177]	valid_0's multi_logloss: 0.194119
# [178]	valid_0's multi_logloss: 0.194021
# [179]	valid_0's multi_logloss: 0.19397
# [180]	valid_0's multi_logloss: 0.193885
# [181]	valid_0's multi_logloss: 0.193792
# [182]	valid_0's multi_logloss: 0.193748
# [183]	valid_0's multi_logloss: 0.193695
# [184]	valid_0's multi_logloss: 0.193637
# [185]	valid_0's multi_logloss: 0.193611
# [186]	valid_0's multi_logloss: 0.193562
# [187]	valid_0's multi_logloss: 0.193513
# [188]	valid_0's multi_logloss: 0.193464
# [189]	valid_0's multi_logloss: 0.193455
# [190]	valid_0's multi_logloss: 0.193374
# [191]	valid_0's multi_logloss: 0.193289
# [192]	valid_0's multi_logloss: 0.193273
# [193]	valid_0's multi_logloss: 0.193274
# [194]	valid_0's multi_logloss: 0.193195
# [195]	valid_0's multi_logloss: 0.193628
# [196]	valid_0's multi_logloss: 0.193849
# [197]	valid_0's multi_logloss: 0.193058
# [198]	valid_0's multi_logloss: 0.192994
# [199]	valid_0's multi_logloss: 0.193007
# [200]	valid_0's multi_logloss: 0.192932
# [201]	valid_0's multi_logloss: 0.192859
# [202]	valid_0's multi_logloss: 0.192812
# [203]	valid_0's multi_logloss: 0.193051
# [204]	valid_0's multi_logloss: 0.19282
# [205]	valid_0's multi_logloss: 0.209944
# Early stopping, best iteration is:
# [105]	valid_0's multi_logloss: 0.189614

# %%
y_pred = np.argmax(lgb.predict_proba(test_x), axis =1)

# %%
y_pred
# Out:
# array([2, 0, 2, ..., 0, 2, 0])

# %%
submission = pd.DataFrame(data=y_pred, columns=sample_submission.columns, index=sample_submission.index)
submission.to_csv("/content/drvie/My Drive/Colab Notebooks/Data/lgbm_submission_0825.csv", index=True)
